# %%
import mysql.connector
from db_config import get_connection

conn = get_connection()
cursor = conn.cursor(dictionary=True)

cursor.execute("SELECT * FROM attendance LIMIT 5")
print("Attendance:", cursor.fetchall())

cursor.execute("SELECT * FROM enrollments WHERE grade IS NOT NULL LIMIT 5")
print("Grades:", cursor.fetchall())

conn.close()
